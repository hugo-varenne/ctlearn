# %%
#---------------------------------------------------------------------------------
#                                 _             _      
#                                | |_  ___ _ __(_)__ _ 
#                                | ' \/ -_) '_ \ / _` |
#                                |_||_\___| .__/_\__,_|
#                                         |_|          
#
#---------------------------------------------------------------------------------
#
# Company: HEPIA // HES-SO
# Engineer: Laurent Gantel <laurent.gantel@hesge.ch>
# 
# Project Name: Unleashing the Full Potential of 
#               High-Performance Cherenkov Telescopes
#               with Fully-Digital Solid-State Sensors Camera
#
# File: 0.2_create_data.ipynb
# Description: Notebook for creating data for CTLearn Manager models
#
# Last update: 2025-08-25
#
#--------------------------------------------------------------------------------

# %% [markdown]
# # SimTel Data

# %%
import ctlearn_manager

# %% [markdown]
# # CTLearn Model Managers

# %% [markdown]
# - Create model manager

# %%
import os
import sys
import importlib
from pathlib import Path
from ctlearn_manager import CTLearnModelManager, DataSample, load_model_from_index

from ctapipe.core import run_tool
from ctapipe.tools.process import ProcessorTool

# %%
# Custom tools
tools_path = os.path.join("..")
if tools_path not in sys.path:
    sys.path.append(tools_path)

import tools.CTLearnMgrConfig as CTLearnMgrConfig
importlib.reload(CTLearnMgrConfig)
import tools.SimtelDataHandler as SimtelDataHandler
importlib.reload(SimtelDataHandler)
# Out:
# <module 'tools.SimtelDataHandler' from '/home/hugo/TM/ml/tools/SimtelDataHandler.py'>

# %%
ctlearn_mgr_config = CTLearnMgrConfig.CTLearnMgrConfig()
ctlearn_mgr_config.load_config('../config/ctlearnmgr_config.yml')
ctlearn_mgr_config.print_config()

# Create the model index file
ctlearn_mgr_config.create_model_index_file()
# Out:
# Base Directory: /home/hugo/TM
# Simtel Relative Directory: data
# Training Samples Directory: samples
# Workspace Directory: ml
# Simtel Path: /home/hugo/TM/data
# Training Samples Path: /home/hugo/TM/data/samples
# Workspace Path: /home/hugo/TM/ml
# Model Index File: /home/hugo/TM/ml/ctlearn_models_index.h5
# Model index file already exists at: /home/hugo/TM/ml/ctlearn_models_index.h5

# %%
# Get tools to convert simtel files to h5
simtel_data_handler = SimtelDataHandler.SimtelDataHandler()

# %% [markdown]
# The first step is to create your ctlearn_model_index file (the Manager will create it for you if it does not exist). It is a HDF5 file containing a table per model. It contains one table per model, regardless of the task it is used for. The parameters table contains the general information about your model, such as its name, directory, reconstruction task, channels, telescopes, and training epochs. Other tables store the training and testing data, the IRFs, and the DL2 files for MC and real data. That way, CTLearn Manager can easily retrieve all relevant data for the plots and IRF production explained below, without the user needing to remember.

# %%
# Convert Simtel files to H5 for gammas diffuse
gammas_dir = os.path.join(ctlearn_mgr_config.training_samples_path, 'gamma')
for root, dirs, files in os.walk(gammas_dir):
    for gammas_filename in files:
        if gammas_filename.endswith('.simtel.gz'):
            simtel_data_handler.convert_simtel_to_h5(root, gammas_filename)
# Out:
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:19,358 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:19,359 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:19,360 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:19,360 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:19,398 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:19,399 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:19,400 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:19,400 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100591.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100591.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:25,269 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:25,270 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:25,271 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:25,271 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:25,321 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:25,322 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:25,323 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:25,323 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100518.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100518.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:30,488 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:30,489 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:30,489 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:30,490 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:30,493 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:30,494 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:30,494 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:30,495 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_110056.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_110056.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:35,740 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:35,740 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:35,741 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:35,741 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:35,779 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:35,780 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:35,780 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:35,781 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100576.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100576.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:40,693 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:40,694 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:40,695 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:40,695 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:40,732 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:40,732 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:40,733 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:40,733 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100506.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100506.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:47,293 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:47,294 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:47,294 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:47,295 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:47,298 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:47,298 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:47,299 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:47,300 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100593.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100593.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:51,570 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:51,571 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:51,571 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:51,572 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:51,613 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:51,614 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:51,614 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:51,615 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_110051.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_110051.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:28:56,411 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:56,411 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:56,412 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:56,412 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:28:56,451 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:56,451 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:56,452 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:28:56,452 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100581.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100581.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:01,270 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:01,270 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:01,271 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:01,271 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:01,275 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:01,275 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:01,276 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:01,276 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100599.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100599.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:05,891 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:05,892 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:05,892 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:05,892 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:05,936 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:05,937 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:05,938 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:05,938 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100596.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100596.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:10,163 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:10,164 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:10,164 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:10,165 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:10,168 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:10,168 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:10,169 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:10,169 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100555.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100555.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:14,952 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:14,953 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:14,954 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:14,954 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:14,993 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:14,994 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:14,994 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:14,995 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/train/gamma_200_800E3GeV_20_20deg_ATM52_100589.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100589.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:21,464 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:21,465 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:21,465 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:21,466 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:21,510 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:21,511 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:21,512 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:21,512 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/test/gamma_200_800E3GeV_20_20deg_ATM52_100505.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100505.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:26,618 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:26,618 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:26,619 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:26,619 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:26,653 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:26,654 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:26,654 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:26,655 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/test/gamma_200_800E3GeV_20_20deg_ATM52_110055.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_110055.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:29:31,341 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:31,342 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:31,343 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:31,343 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:29:31,379 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:31,379 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:31,380 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:29:31,380 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/gamma/test/gamma_200_800E3GeV_20_20deg_ATM52_100575.corsika.gz.NSBmed4.simtel.gz to gamma_200_800E3GeV_20_20deg_ATM52_100575.corsika.gz.NSBmed4.simtel.h5

# %%
# Convert Simtel files to H5 for protons diffuse
protons_dir = os.path.join(ctlearn_mgr_config.training_samples_path, 'proton')
for root, dirs, files in os.walk(protons_dir):
    for protons_filename in files:
        if protons_filename.endswith('.simtel.gz'):
            simtel_data_handler.convert_simtel_to_h5(root, protons_filename)
# Out:
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:31:47,814 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:31:47,814 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:31:47,815 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:31:47,816 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:31:47,855 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:31:47,856 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:31:47,856 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:31:47,857 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_212060.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_212060.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:32:01,528 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:01,529 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:01,530 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:01,530 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:01,571 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:01,571 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:01,572 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:01,572 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206085.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206085.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:32:13,172 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:13,172 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:13,173 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:13,173 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:13,205 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:13,206 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:13,206 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:13,207 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206011.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206011.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:32:24,044 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:24,045 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:24,046 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:24,046 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:24,085 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:24,086 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:24,086 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:24,087 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206064.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206064.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:32:35,584 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:35,585 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:35,585 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:35,586 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:35,627 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:35,627 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:35,628 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:35,628 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206066.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206066.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:32:50,815 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:50,816 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:50,816 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:50,817 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:32:50,849 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:50,850 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:50,850 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:32:50,851 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206077.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206077.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:00,075 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:00,075 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:00,075 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:00,076 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:00,108 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:00,109 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:00,109 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:00,110 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206061.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206061.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:11,030 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:11,031 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:11,032 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:11,032 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:11,070 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:11,070 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:11,071 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:11,071 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206032.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206032.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:24,504 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:24,504 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:24,505 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:24,505 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:24,551 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:24,552 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:24,552 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:24,553 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206088.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206088.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:37,654 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:37,654 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:37,655 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:37,655 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:37,691 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:37,691 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:37,692 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:37,692 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206043.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206043.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:47,997 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:47,998 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:47,999 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:47,999 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:48,038 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:48,039 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:48,039 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:48,039 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_206095.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206095.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:33:58,794 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:58,795 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:58,796 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:58,796 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:33:58,828 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:58,829 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:58,830 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:33:58,830 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/train/proton_400_1300E3GeV_20_20deg_ATM52_202060.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_202060.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:34:10,217 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:10,217 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:10,218 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:10,219 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:10,265 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:10,265 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:10,266 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:10,266 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/test/proton_400_1300E3GeV_20_20deg_ATM52_206029.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206029.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:34:21,639 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:21,640 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:21,640 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:21,641 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:21,644 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:21,645 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:21,645 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:21,646 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/test/proton_400_1300E3GeV_20_20deg_ATM52_206075.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206075.corsika.gz.NSBmed4.simtel.h5
# SimTelEventSource: 0ev [00:00, ?ev/s]
# 2025-09-19 14:34:36,754 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:36,754 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:36,755 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:36,755 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_001 not writable, skipping
# 2025-09-19 14:34:36,759 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column first_cell_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:36,760 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column module_hires_local_clock_counter with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:36,760 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column pedestal_intensity with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# 2025-09-19 14:34:36,761 WARNING [ctapipe.ctapipe-process.DataWriter.HDF5TableWriter] (hdf5tableio._create_hdf5_table_schema): Column calibration_monitoring_id with value None of type <class 'NoneType'>  of container R1CameraContainer in table r1/event/telescope/tel_002 not writable, skipping
# Successfully converted /home/hugo/TM/data/samples/proton/test/proton_400_1300E3GeV_20_20deg_ATM52_206092.corsika.gz.NSBmed4.simtel.gz to proton_400_1300E3GeV_20_20deg_ATM52_206092.corsika.gz.NSBmed4.simtel.h5
