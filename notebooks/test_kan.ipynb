# %% [markdown]
# # Test of KAN neural architecture
#
# ### Imports

# %%
import torch
from kan import *

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Create Model

# %%
# Width = number of n
model = KAN(width=[4, 5, 3], grid=5, k=3)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Width = number of n
# ----> 2 model = KAN(width=[4, 5, 3], grid=5, k=3)
#
# File ~/miniforge3/envs/ctlearn/lib/python3.10/site-packages/kan/MultKAN.py:283, in MultKAN.__init__(self, width, grid, k, mult_arity, noise_scale, scale_base_mu, scale_base_sigma, base_fun, symbolic_enabled, affine_trainable, grid_eps, grid_range, sp_trainable, sb_trainable, seed, save_act, sparse_init, auto_save, first_init, ckpt_path, state_id, round, device)
#     281         file.write(f'### Round {self.round} ###' + '\n')
#     282         file.write('init => 0.0' + '\n')
# --> 283     self.saveckpt(path=self.ckpt_path+'/'+'0.0')
#     284 else:
#     285     self.state_id = state_id
#
# ...
