# %%
#---------------------------------------------------------------------------------
#                                 _             _      
#                                | |_  ___ _ __(_)__ _ 
#                                | ' \/ -_) '_ \ / _` |
#                                |_||_\___| .__/_\__,_|
#                                         |_|          
#
#---------------------------------------------------------------------------------
#
# Company: HEPIA // HES-SO
# Engineer: Laurent Gantel <laurent.gantel@hesge.ch>
# 
# Project Name: Unleashing the Full Potential of 
#               High-Performance Cherenkov Telescopes
#               with Fully-Digital Solid-State Sensors Camera
#
# File: 2.1_monitor_model.ipynb
# Description: Notebook for monitoring model architecture
#
# Last update: 2025-09-04
#
#--------------------------------------------------------------------------------

# %%
import sys
import os
import importlib
from ctlearn_manager import load_model_from_index
import astropy.units as u
# Constant 
RECO = "type"

# %%
# Custom tools
tools_path = os.path.join("../tools")
if tools_path not in sys.path:
    sys.path.append(tools_path)

import tools.CTLearnMgrConfig as CTLearnMgrConfig
importlib.reload(CTLearnMgrConfig)
# Out:
# <module 'tools.CTLearnMgrConfig' from '/home/hugo/TM/ml/tools/CTLearnMgrConfig.py'>

# %%
ctlearn_mgr_config = CTLearnMgrConfig.CTLearnMgrConfig()
ctlearn_mgr_config.load_config('../config/ctlearnmgr_config.yml')
ctlearn_mgr_config.print_config()
# Out:
# Base Directory: /home/hugo/TM
# Simtel Relative Directory: data
# Training Samples Directory: samples
# Workspace Directory: ml
# Simtel Path: /home/hugo/TM/data
# Training Samples Path: /home/hugo/TM/data/samples
# Workspace Path: /home/hugo/TM/ml
# Model Index File: /home/hugo/TM/ml/ctlearn_models_index.h5

# %%
# First, we load our model from the index
model = load_model_from_index(f"{RECO}_tel2_20deg_20", ctlearn_mgr_config.model_index_file)
model.cluster_configuration.info()
# Out:
# 🔧 Not using any cluster

# %%
# Model checkpoint is stored into type_tel2_20deg/type_tel2_20deg_v0/ctlearn_model.cpk/saved_model.pb
# Load the model checkpoint
import tensorflow as tf
model = tf.keras.models.load_model(os.path.join(ctlearn_mgr_config.workspace_path, f"{RECO}_tel2_20deg", f"{RECO}_tel2_20deg_v0", "ctlearn_model.cpk"))
model.summary()
# Out:
# 2025-09-25 08:02:12.702921: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-25 08:02:12.749827: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-25 08:02:12.968660: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-25 08:02:12.968709: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-25 08:02:12.970208: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-25 08:02:13.092141: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-25 08:02:13.093883: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-25 08:02:14.559813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "CTLearn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 2)]       0
#
#  ThinResNet_block (Function  (None, 1024)              5926315
#  al)
#
#  fc_type_1 (Dense)           (None, 512)               524800
#
#  fc_type_2 (Dense)           (None, 256)               131328
#
#  type (Dense)                (None, 2)                 514
#
#  softmax (Softmax)           (None, 2)                 0
#
# =================================================================
# Total params: 6582957 (25.11 MB)
# Trainable params: 6582957 (25.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Out:
# Model: "CTLearn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 96, 96, 2)]       0
#
#  SingleCNN_block (Functiona  (None, 128)               102208
#  l)
#
#  fc_type_1 (Dense)           (None, 512)               66048
#
#  fc_type_2 (Dense)           (None, 256)               131328
#
#  type (Dense)                (None, 2)                 514
#
#  softmax_19 (Softmax)        (None, 2)                 0
#
# =================================================================
# Total params: 300098 (1.14 MB)
# Trainable params: 300098 (1.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
